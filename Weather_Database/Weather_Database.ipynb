# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 643

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description =city_weather["weather"][0]["description"]

            # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=ushtobe
# Processing Record 1 of Set 1 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=deputatskiy
# Processing Record 2 of Set 1 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=akureyri
# Processing Record 3 of Set 1 | akureyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=mataura
# Processing Record 4 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=necochea
# Processing Record 5 of Set 1 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=tunceli
# Processing Record 6 of Set 1 | tunceli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=saskylakh
# Processing Record 7 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=ushuaia
# Processing Record 8 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=charters+towers
# Processing Record 1 of Set 12 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=milingimbi
# Processing Record 2 of Set 12 | milingimbi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=rameswaram
# Processing Record 3 of Set 12 | rameswaram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=oksfjord
# Processing Record 4 of Set 12 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=disna
# Processing Record 5 of Set 12 | disna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=bengkulu
# Processing Record 6 of Set 12 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=komsomolets
# Processing Record 7 of Set 12 | komsomolets
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=cayenne
# Processing Record 8 of Set 12 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=bijar
# Processing Record 9 of Set 12 | bijar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=karamea
# Processing Record 10 of Set 12 | karamea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=truckee
# Processing Record 11 of Set 12 | truckee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=newcastleton
# Processing Record 12 of Set 12 | newcastleton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=zarubino
# Processing Record 13 of Set 12 | zarubino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=aracuai
# Processing Record 14 of Set 12 | aracuai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=erdenet
# Processing Record 15 of Set 12 | erdenet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=calderitas
# Processing Record 16 of Set 12 | calderitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=vagur
# Processing Record 17 of Set 12 | vagur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=angoche
# Processing Record 18 of Set 12 | angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=borgarnes
# Processing Record 19 of Set 12 | borgarnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=areka
# Processing Record 20 of Set 12 | areka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=dzhalil
# Processing Record 21 of Set 12 | dzhalil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=ust-karsk
# Processing Record 22 of Set 12 | ust-karsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=porto+novo
# Processing Record 23 of Set 12 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=imbituba
# Processing Record 24 of Set 12 | imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=susangerd
# Processing Record 25 of Set 12 | susangerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=lalibela
# Processing Record 26 of Set 12 | lalibela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=kulhudhuffushi
# Processing Record 27 of Set 12 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=muros
# Processing Record 28 of Set 12 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=ullal
# Processing Record 29 of Set 12 | ullal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=araouane
# Processing Record 30 of Set 12 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=dunmore+east
# Processing Record 31 of Set 12 | dunmore east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=bathsheba
# Processing Record 32 of Set 12 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=kupino
# Processing Record 33 of Set 12 | kupino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=knysna
# Processing Record 34 of Set 12 | knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=vryburg
# Processing Record 35 of Set 12 | vryburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=lac+du+bonnet
# Processing Record 36 of Set 12 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=zaranj
# Processing Record 37 of Set 12 | zaranj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=nipawin
# Processing Record 38 of Set 12 | nipawin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=mareeba
# Processing Record 39 of Set 12 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=jawhar
# Processing Record 40 of Set 12 | jawhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=kununurra
# Processing Record 41 of Set 12 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=longlac
# Processing Record 42 of Set 12 | longlac
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=sangar
# Processing Record 43 of Set 12 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=umm+lajj
# Processing Record 44 of Set 12 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=tombouctou
# Processing Record 45 of Set 12 | tombouctou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=sistranda
# Processing Record 46 of Set 12 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=bundaberg
# Processing Record 47 of Set 12 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=camopi
# Processing Record 48 of Set 12 | camopi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=uyar
# Processing Record 49 of Set 12 | uyar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=bodrum
# Processing Record 50 of Set 12 | bodrum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=monte+escobedo
# Processing Record 1 of Set 13 | monte escobedo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=cabo+san+lucas
# Processing Record 2 of Set 13 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=ketchikan
# Processing Record 3 of Set 13 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=pemangkat
# Processing Record 4 of Set 13 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=mbekenyera
# Processing Record 5 of Set 13 | mbekenyera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=sola
# Processing Record 6 of Set 13 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=amahai
# Processing Record 7 of Set 13 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=rawson
# Processing Record 8 of Set 13 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=san+lawrenz
# Processing Record 9 of Set 13 | san lawrenz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=nuristan
# Processing Record 10 of Set 13 | nuristan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=bridlington
# Processing Record 11 of Set 13 | bridlington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a68e015cefb39de14427a0f8014dc07b&q=ponnampet
# Processing Record 12 of Set 13 | ponnampet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 591

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushtobe  45.2514   77.9838     34.18        68          60        3.96
# 1  Deputatskiy  69.3000  139.9000    -21.24        99          57        4.25
# 2     Akureyri  65.6835  -18.0878     37.51       100         100        5.26
# 3      Mataura -46.1927  168.8643     77.11        34           0        0.22
# 4     Necochea -38.5473  -58.7368     63.70        67          70        4.59
# 5      Tunceli  39.1083   39.5471     45.46        83          49        3.00
# 6    Saskylakh  71.9167  114.0833    -27.54       100          45        3.00
# 7      Ushuaia -54.8000  -68.3000     44.26        65          20       11.50
# 8       Bethel  41.3712  -73.4140     59.36        79           0        5.75
# 9      Qaanaaq  77.4840  -69.3632     -7.02        58           0        8.12
#
#   Country Current Description
# 0      KZ       broken clouds
# 1      RU       broken clouds
# 2      IS     overcast clouds
# 3      NZ           clear sky
# 4      AR       broken clouds
# 5      TR    scattered clouds
# 6      RU    scattered clouds
# 7      AR          few clouds
# 8      US           clear sky
# 9      GL           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ushtobe      KZ  45.2514   77.9838     34.18        68          60
# 1  Deputatskiy      RU  69.3000  139.9000    -21.24        99          57
# 2     Akureyri      IS  65.6835  -18.0878     37.51       100         100
# 3      Mataura      NZ -46.1927  168.8643     77.11        34           0
# 4     Necochea      AR -38.5473  -58.7368     63.70        67          70
# 5      Tunceli      TR  39.1083   39.5471     45.46        83          49
# 6    Saskylakh      RU  71.9167  114.0833    -27.54       100          45
# 7      Ushuaia      AR -54.8000  -68.3000     44.26        65          20
# 8       Bethel      US  41.3712  -73.4140     59.36        79           0
# 9      Qaanaaq      GL  77.4840  -69.3632     -7.02        58           0
#
#    Wind Speed Current Description
# 0        3.96       broken clouds
# 1        4.25       broken clouds
# 2        5.26     overcast clouds
# 3        0.22           clear sky
# 4        4.59       broken clouds
# 5        3.00    scattered clouds
# 6        3.00    scattered clouds
# 7       11.50          few clouds
# 8        5.75           clear sky
# 9        8.12           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
